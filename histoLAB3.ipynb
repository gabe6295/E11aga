# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('rpA1.csv')
display(data)
plt.hist(data["{'pm25 env': 0}"])
# Out:
#         1771027700.3786228  {'pm25 env': 0}
# 0             1.771028e+09         0.462593
# 1             1.771028e+09         0.971288
# 2             1.771028e+09         0.103333
# 3             1.771028e+09         0.237194
# 4             1.771028e+09         0.242551
# ...                    ...              ...
# 552633        1.771028e+09         0.343997
# 552634        1.771028e+09         0.699948
# 552635        1.771028e+09         0.719091
# 552636        1.771028e+09         0.715400
# 552637        1.771028e+09              NaN
#
# [552638 rows x 2 columns]
# (array([55340., 55399., 55153., 55382., 55301., 55375., 54669., 55597.,
#         55210., 55211.]),
#  array([4.59026231e-06, 1.00004103e-01, 2.00003616e-01, 3.00003129e-01,
#         4.00002641e-01, 5.00002154e-01, 6.00001667e-01, 7.00001179e-01,
#         8.00000692e-01, 9.00000205e-01, 9.99999718e-01]),
#  <BarContainer object of 10 artists>)
