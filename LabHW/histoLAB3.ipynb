# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
cwd = Path.cwd()
rpPath = cwd / 'datafolder' / 'rpA1.csv'

data = pd.read_csv(rpPath)
display(data)
plt.hist(data["PM25"])
plt.title('rpA1')
plt.show()
# Out:
#            Timestamp      PM25
# 0       1.771028e+09  0.462593
# 1       1.771028e+09  0.971288
# 2       1.771028e+09  0.103333
# 3       1.771028e+09  0.237194
# 4       1.771028e+09  0.242551
# ...              ...       ...
# 552632  1.771028e+09  0.191079
# 552633  1.771028e+09  0.343997
# 552634  1.771028e+09  0.699948
# 552635  1.771028e+09  0.719091
# 552636  1.771028e+09  0.715400
#
# [552637 rows x 2 columns]
